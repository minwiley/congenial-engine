# %%
# dependencies
import random
import pandas as pd
import requests
import json
import numpy as np
import glob
import matplotlib.pyplot as plt
import json

# %%
sample15_16 = "sample_2015-2016_wYears.csv"
sample_df = pd.read_csv(sample15_16 , index_col=None, header=0)
sample_df.head()
# Out:
#    Duration           Start date             End date  Start station number  \
# 0      6023  2015-01-01 00:35:55  2015-01-01 02:16:19                 31503
# 1       717  2015-01-01 01:04:42  2015-01-01 01:16:40                 31252
# 2       654  2015-01-01 01:13:50  2015-01-01 01:24:44                 31603
# 3       418  2015-01-01 01:17:19  2015-01-01 01:24:18                 31104
# 4       110  2015-01-01 01:59:03  2015-01-01 02:00:54                 31603
#
#                    Start station  End station number  \
# 0          Florida Ave & R St NW               31508
# 1  21st St & Pennsylvania Ave NW               31258
# 2                  1st & M St NE               31632
# 3    Adams Mill & Columbia Rd NW               31119
# 4                  1st & M St NE               31603
#
#                            End station Bike number Member type  Years
# 0  Gallaudet / 8th St & Florida Ave NE      W00170      Member   2015
# 1                     Lincoln Memorial      W20243      Member   2015
# 2                       15th & F St NE      W20217      Member   2015
# 3                 14th & Belmont St NW      W00645      Member   2015
# 4                        1st & M St NE      W20703      Member   2015

# %%
bike_location_file = "bike_station_location.csv"
bike_location_df = pd.read_csv(bike_location_file,index_col=None, header=0)
bike_location_df.head(2)
# Out:
#     OBJECTID   ID                             ADDRESS  TERMINAL_NUMBER  \
# 0  223143627  434  Town Center Pkwy & Bowman Towne Dr            32210
# 1  223143628  435             Reston Regional Library            32211
#
#     LATITUDE  LONGITUDE INSTALLED LOCKED  INSTALL_DATE  REMOVAL_DATE  \
# 0  38.962524 -77.361902       YES     NO           NaN           NaN
# 1  38.962095 -77.358815       YES     NO           NaN           NaN
#
#   TEMPORARY_INSTALL  NUMBER_OF_BIKES  NUMBER_OF_EMPTY_DOCKS            X  \
# 0                NO                8                      7  368634.8196
# 1                NO                7                      7  368902.1739
#
#              Y  SE_ANNO_CAD_DATA OWNER
# 0  143908.1787               NaN   NaN
# 1  143859.4999               NaN   NaN

# %%
bike_renamed_df = bike_location_df.rename(columns={"TERMINAL_NUMBER":"Start station number"})
bike_renamed_df.head(2)
# Out:
#     OBJECTID   ID                             ADDRESS  Start station number  \
# 0  223143627  434  Town Center Pkwy & Bowman Towne Dr                 32210
# 1  223143628  435             Reston Regional Library                 32211
#
#     LATITUDE  LONGITUDE INSTALLED LOCKED  INSTALL_DATE  REMOVAL_DATE  \
# 0  38.962524 -77.361902       YES     NO           NaN           NaN
# 1  38.962095 -77.358815       YES     NO           NaN           NaN
#
#   TEMPORARY_INSTALL  NUMBER_OF_BIKES  NUMBER_OF_EMPTY_DOCKS            X  \
# 0                NO                8                      7  368634.8196
# 1                NO                7                      7  368902.1739
#
#              Y  SE_ANNO_CAD_DATA OWNER
# 0  143908.1787               NaN   NaN
# 1  143859.4999               NaN   NaN

# %%
merge_table = pd.merge(sample_df, bike_renamed_df, on="Start station number", how="left")
merge_table.head(2)
# Out:
#    Duration           Start date             End date  Start station number  \
# 0      6023  2015-01-01 00:35:55  2015-01-01 02:16:19                 31503
# 1       717  2015-01-01 01:04:42  2015-01-01 01:16:40                 31252
#
#                    Start station  End station number  \
# 0          Florida Ave & R St NW               31508
# 1  21st St & Pennsylvania Ave NW               31258
#
#                            End station Bike number Member type  Years  ...   \
# 0  Gallaudet / 8th St & Florida Ave NE      W00170      Member   2015  ...
# 1                     Lincoln Memorial      W20243      Member   2015  ...
#
#    LOCKED  INSTALL_DATE REMOVAL_DATE  TEMPORARY_INSTALL  NUMBER_OF_BIKES  \
# 0      NO           NaN          NaN                 NO              0.0
# 1      NO           NaN          NaN                 NO             13.0
#
#   NUMBER_OF_EMPTY_DOCKS            X            Y  SE_ANNO_CAD_DATA OWNER
# 0                  14.0  398829.1647  138304.0906               NaN    DC
# 1                   5.0  395960.9460  137077.1730               NaN    DC
#
# [2 rows x 26 columns]

# %%
merge_table_some_col = merge_table[['Duration', 'Start date', 'End date', 'Start station number', 
                                'Start station', 'End station number', 'End station', 'Bike number',
                                'Member type', 'ADDRESS', 'LATITUDE', 'LONGITUDE']]
merge_table_some_col.head(2)
# Out:
#    Duration           Start date             End date  Start station number  \
# 0      6023  2015-01-01 00:35:55  2015-01-01 02:16:19                 31503
# 1       717  2015-01-01 01:04:42  2015-01-01 01:16:40                 31252
#
#                    Start station  End station number  \
# 0          Florida Ave & R St NW               31508
# 1  21st St & Pennsylvania Ave NW               31258
#
#                            End station Bike number Member type  \
# 0  Gallaudet / 8th St & Florida Ave NE      W00170      Member
# 1                     Lincoln Memorial      W20243      Member
#
#                          ADDRESS   LATITUDE  LONGITUDE
# 0          Florida Ave & R St NW  38.912600 -77.013500
# 1  21st St & Pennsylvania Ave NW  38.901539 -77.046564

# %%
merge_table_rename = merge_table_some_col.rename(columns={'Duration': 'Duration', 'Start date': 'Start date', 
                                                           'End date': 'End date', 'Start station number': 'Start station #', 
                                                           'Start station': 'Start station', 'LATITUDE' : 'Start Station Lat', 
                                                           'LONGITUDE': 'Start Station Lng', 'End station number': 'End station #', 
                                                           'End station': 'End station', 'Bike number': 'Bike number',
                                                           'Member type': 'Member type'
                                                          })
merge_table_rename.head()
# Out:
#    Duration           Start date             End date  Start station #  \
# 0      6023  2015-01-01 00:35:55  2015-01-01 02:16:19            31503
# 1       717  2015-01-01 01:04:42  2015-01-01 01:16:40            31252
# 2       654  2015-01-01 01:13:50  2015-01-01 01:24:44            31603
# 3       418  2015-01-01 01:17:19  2015-01-01 01:24:18            31104
# 4       110  2015-01-01 01:59:03  2015-01-01 02:00:54            31603
#
#                    Start station  End station #  \
# 0          Florida Ave & R St NW          31508
# 1  21st St & Pennsylvania Ave NW          31258
# 2                  1st & M St NE          31632
# 3    Adams Mill & Columbia Rd NW          31119
# 4                  1st & M St NE          31603
#
#                            End station Bike number Member type  \
# 0  Gallaudet / 8th St & Florida Ave NE      W00170      Member
# 1                     Lincoln Memorial      W20243      Member
# 2                       15th & F St NE      W20217      Member
# 3                 14th & Belmont St NW      W00645      Member
# 4                        1st & M St NE      W20703      Member
#
#                          ADDRESS  Start Station Lat  Start Station Lng
# 0          Florida Ave & R St NW          38.912600         -77.013500
# 18                          Jefferson Dr & 14th St SW      W00675      Casual
# 19                      21st St & Pennsylvania Ave NW      W20928      Casual
# 20                                     10th & E St NW      W20483      Member
# 21                          New York Ave & 15th St NW      W01285      Member
# 22                               14th & Harvard St NW      W00206      Member
# 23                                   Lincoln Memorial      W20378      Casual
# 24                   Hains Point/Buckeye & Ohio Dr SW      W00204      Member
# 25                                     14th & G St NW      W01404      Member
# 26                           M St & New Jersey Ave SE      W21283      Member
# 27                                     10th & E St NW      W20817      Member
# 28                                      8th & D St NW      W21815      Casual
# 29                               14th & Belmont St NW      W01330      Member
# ...                                               ...         ...         ...
# 79970                                   3rd & M St NE      W00619      Member
# 79971                              3rd & Tingey St SE      W22741      Member
# 79972                                   7th & T St NW      W20174      Member
# 79973            Massachusetts Ave & Dupont Circle NW      W22397      Member
# 79974       Lincoln Park / 13th & East Capitol St NE       W22415      Member
# 79975                                Lincoln Memorial      W20048      Casual
# 79976               Convention Center / 7th & M St NW      W23036      Member
# 79977                                  24th & N St NW      W22893      Member
# 79978                       Jefferson Dr & 14th St SW      W22287      Casual
# 79979                   5th St & Massachusetts Ave NW      W22437      Casual
# 79980                       Jefferson Dr & 14th St SW      W01256      Member
# 79981                                   1st & K St SE      W20969      Member
# 79982                                  17th & K St NW      W22382      Member
# 79983         14th & D St NW / Ronald Reagan Building      W01227      Casual
# 79984                                  18th & C St NW      W22656      Casual
# 79985                     New Hampshire Ave & T St NW      W21328      Member
# 79986                            14th & Belmont St NW      W21471      Member
# 79987                                  11th & H St NE      W20905      Member
# 79988                         Potomac Ave & 8th St SE      W20044      Casual
# 79989                           10th & Florida Ave NW      W21198      Member
# 79990                             14th & Irving St NW      W22804      Member
# 79991                        4th & East Capitol St NE      W01328      Member
# 79992                        4th & East Capitol St NE      W21757      Casual
# 79993       7th & F St NW / National Portrait Gallery      W23061      Casual
# 79994                      M St & Pennsylvania Ave NW      W22937      Member
# 79995                                   1st & M St NE      W22289      Member
# 79996                              9th & Upshur St NW      W22234      Member
# 79997                                   8th & O St NW      W22837      Member
# 79998                      14th & Rhode Island Ave NW      W22958      Member
# 79999                                   7th & T St NW      W01263      Member
#
#                                                ADDRESS_x  ...    LOCKED  \
# 0                                  Florida Ave & R St NW  ...        NO
# 1                          21st St & Pennsylvania Ave NW  ...        NO
# 2                                          1st & M St NE  ...        NO
# 3                            Adams Mill & Columbia Rd NW  ...        NO
# 4                                          1st & M St NE  ...        NO
# 5                   Massachusetts Ave & Dupont Circle NW  ...        NO
# 6                                         24th & N St NW  ...        NO
# 7                            New Hampshire Ave & T St NW  ...        NO
# 8                                 Eckington Pl & Q St NE  ...        NO
# 9                              Jefferson Dr & 14th St SW  ...        NO
# 10                         25th St & Pennsylvania Ave NW  ...        NO
# 11     Smithsonian-National Mall / Jefferson Dr & 12t...  ...        NO
# 12                         5th St & Massachusetts Ave NW  ...        NO
# 13                                         3rd & H St NE  ...        NO
# 14                                        20th & E St NW  ...        NO
# 15                         19th St & Pennsylvania Ave NW  ...        NO
# 16                   1st & Washington Hospital Center NW  ...        NO
# 17                                         4th & M St SW  ...        NO
# 18                                        11th & F St NW  ...        NO
# 19                3000 Connecticut Ave NW / National Zoo  ...        NO
# 20                                   11th & Kenyon St NW  ...        NO
# 21                          7th & R St NW / Shaw Library  ...        NO
# 22                                14th St & Spring Rd NW  ...        NO
# 23                             Jefferson Dr & 14th St SW  ...        NO
# 24                                        1st & N St  SE  ...        NO
# 25                         5th St & Massachusetts Ave NW  ...        NO
# 26                                Eckington Pl & Q St NE  ...        NO
# 27              Lincoln Park / 13th & East Capitol St NE  ...        NO
# 28                                         3rd & M St NE  ...        NO
# 29                3000 Connecticut Ave NW / National Zoo  ...        NO
# ...                                                  ...  ...       ...
# 79970                                     13th & D St NE  ...        NO
# 79971                                      1st & K St SE  ...        NO
# 79972                                     14th & V St NW  ...        NO
# 79973                        Adams Mill & Columbia Rd NW  ...        NO
# 79974  Eastern Market Metro / Pennsylvania Ave & 7th ...  ...        NO
# 79975                                     24th & N St NW  ...        NO
# 79976                John McCormack Dr & Michigan Ave NE  ...        NO
# 79977                                     15th & L St NW  ...        NO
# 79978  Smithsonian-National Mall / Jefferson Dr & 12t...  ...        NO
# 79979                          14th St & New York Ave NW  ...        NO
# 79980           Lincoln Park / 13th & East Capitol St NE  ...        NO
# 79981                                 3rd & Tingey St SE  ...        NO
# 79982                                      3rd & H St NW  ...        NO
# 79983                          20th St & Virginia Ave NW  ...        NO
# 79984                      19th St & Constitution Ave NW  ...        NO
# 79985                              17th & Corcoran St NW  ...        NO
# 79986                            Park Rd & Holmead Pl NW  ...        NO
# 79987                                      8th & H St NW  ...        NO
# 79988                            Potomac Ave & 8th St SE  ...        NO
# 79989                          14th St & New York Ave NW  ...        NO
# 79990                                      1st & H St NW  ...        NO
# 79991                                      3rd & H St NE  ...        NO
# 79992                      19th St & Pennsylvania Ave NW  ...        NO
# 79993            14th & D St NW / Ronald Reagan Building  ...        NO
# 79994                                     19th & G St NW  ...        NO
# 79995                Gallaudet / 8th St & Florida Ave NE  ...        NO
# 79996                        Adams Mill & Columbia Rd NW  ...        NO
# 79997                         14th & Rhode Island Ave NW  ...        NO
# 79998                                      7th & T St NW  ...        NO
# 79999                                     14th & V St NW  ...        NO
#
#        INSTALL_DATE  REMOVAL_DATE  TEMPORARY_INSTALL NUMBER_OF_BIKES  \
# 0               NaN           NaN                 NO             1.0
# 1               NaN           NaN                 NO             5.0
# 2               NaN           NaN                 NO             0.0
# 3               NaN           NaN                 NO             6.0
# 4               NaN           NaN                 NO             6.0
# 5               NaN           NaN                 NO            11.0
# 6               NaN           NaN                 NO             3.0
# 7               NaN           NaN                 NO             4.0
# 8               NaN           NaN                 NO             1.0
# 9               NaN           NaN                 NO             2.0
# 10              NaN           NaN                 NO             2.0
# 11              NaN           NaN                 NO             5.0
# 12              NaN           NaN                 NO             5.0
# 13              NaN           NaN                 NO             1.0
# 14              NaN           NaN                 NO            13.0
# 15              NaN           NaN                 NO             8.0
# 16              NaN           NaN                 NO             4.0
# 17              NaN           NaN                 NO             4.0
# 18              NaN           NaN                 NO             2.0
# 22                      19.0  397207.8970  139880.8160              NaN     DC
# 23                      17.0  395711.8918  135602.2305              NaN     DC
# 24                      15.0  397376.9402  134511.6305              NaN     DC
# 25                       7.0  397253.1066  136726.5000              NaN     DC
# 26                      10.0  399678.9411  134274.4235              NaN     DC
# 27                       8.0  397738.9784  136452.0457              NaN     DC
# 28                       0.0  397983.9271  136333.9781              NaN     DC
# 29                       9.0  397234.8156  139245.1718              NaN     DC
# ...                      ...          ...          ...              ...    ...
# 79970                   22.0  399815.2497  137512.5178              NaN     DC
# 79971                    2.0  399791.7418  134131.2200              NaN     DC
# 79972                   14.0  398074.7047  138626.1622              NaN     DC
# 79973                   26.0  396149.1179  138027.4199              NaN     DC
# 79974                   22.0  401010.2674  135846.4614              NaN     DC
# 79975                   17.0  395711.8918  135602.2305              NaN     DC
# 79976                   22.0  398068.3695  137542.3904              NaN     DC
# 79977                    6.0  395531.3698  137639.2158              NaN     DC
# 79978                   19.0  397186.5319  135635.0937              NaN     DC
# 79979                   13.0  398379.9060  137008.7047              NaN     DC
# 79980                   19.0  397186.5319  135635.0937              NaN     DC
# 79981                   11.0  399503.0706  134557.9460              NaN     DC
# 79982                    8.0  396649.2143  137212.3926              NaN     DC
# 79983                   12.0  397257.2084  136296.7868              NaN     DC
# 79984                   14.0  396395.9852  136185.7910              NaN     DC
# 79985                   19.0  396688.8408  138631.0609              NaN     DC
# 79986                    9.0  397234.8156  139245.1718              NaN     DC
# 79987                   17.0  400747.4721  136903.4496              NaN     DC
# 79988                    4.0  400480.0235  134322.9419              NaN     DC
# 79989                   12.0  397773.7480  139168.7391              NaN     DC
# 79990                   28.0  397205.8846  140075.3037              NaN     DC
# 79991                    6.0  399969.7221  135790.2270              NaN     DC
# 79992                    6.0  399969.7221  135790.2270              NaN     DC
# 79993                   10.0  397970.8120  136610.7242              NaN     DC
# 79994                   12.0  395065.7567  137475.8662              NaN     DC
# 79995                    4.0  399514.2732  137538.0624              NaN     DC
# 79996                   14.0  397824.0048  141545.7535              NaN     DC
# 79997                   16.0  398025.0815  137864.6578              NaN     DC
# 79998                   23.0  397198.5110  137860.4668              NaN     DC
# 79999                   14.0  398074.7047  138626.1622              NaN     DC
#
# [80000 rows x 28 columns]

# %%
merge_table2.columns
# Out:
# Index(['Duration', 'Start date', 'End date', 'Start station #',
#        'Start station', 'End station #', 'End station', 'Bike number',
#        'Member type', 'ADDRESS_x', 'Start Station Lat', 'Start Station Lng',
#        'OBJECTID', 'ID', 'ADDRESS_y', 'LATITUDE', 'LONGITUDE', 'INSTALLED',
#        'LOCKED', 'INSTALL_DATE', 'REMOVAL_DATE', 'TEMPORARY_INSTALL',
#        'NUMBER_OF_BIKES', 'NUMBER_OF_EMPTY_DOCKS', 'X', 'Y',
#        'SE_ANNO_CAD_DATA', 'OWNER'],
#       dtype='object')

# %%
sample_fin = merge_table2[['Duration', 
                        'Start date', 
                        'End date', 
                        'Start station #',
                        'Start station', 
                        'Start Station Lat', 
                        'Start Station Lng',                                       
                        'End station #', 
                        'End station', 
                        'LATITUDE', 
                        'LONGITUDE',
                        'Bike number',
                        'Member type', 
                        'REMOVAL_DATE',
                        'NUMBER_OF_BIKES'
                       ]]
sample_fin.head()
# Out:
#    Duration           Start date             End date  Start station #  \
# 0      6023  2015-01-01 00:35:55  2015-01-01 02:16:19            31503
# 1       717  2015-01-01 01:04:42  2015-01-01 01:16:40            31252
# 2       654  2015-01-01 01:13:50  2015-01-01 01:24:44            31603
# 3       418  2015-01-01 01:17:19  2015-01-01 01:24:18            31104
# 4       110  2015-01-01 01:59:03  2015-01-01 02:00:54            31603
#
#                    Start station  Start Station Lat  Start Station Lng  \
# 0          Florida Ave & R St NW          38.912600         -77.013500
# 1  21st St & Pennsylvania Ave NW          38.901539         -77.046564
# 2                  1st & M St NE          38.905700         -77.005600
# 3    Adams Mill & Columbia Rd NW          38.922925         -77.042581
# 4                  1st & M St NE          38.905700         -77.005600
#
#    End station #                          End station   LATITUDE  LONGITUDE  \
# 0          31508  Gallaudet / 8th St & Florida Ave NE  38.905090 -76.994100
# 1          31258                     Lincoln Memorial  38.888251 -77.049426
# 2          31632                       15th & F St NE  38.897195 -76.983575
# 3          31119                 14th & Belmont St NW  38.921074 -77.031887
# 4          31603                        1st & M St NE  38.905700 -77.005600
#
#   Bike number Member type  REMOVAL_DATE  NUMBER_OF_BIKES
# 0      W00170      Member           NaN              1.0
# 1      W20243      Member           NaN              5.0
# 2      W20217      Member           NaN              0.0
# 3      W00645      Member           NaN              6.0
# 4      W20703      Member           NaN              6.0

# %%
# sample_fin.to_csv("AllSampleWYears_lat&lng.csv", index=False)

# %%
sample_fin.describe()
# Out:
#            Duration  Start station #  Start Station Lat  Start Station Lng  \
# count  80000.000000     80000.000000       79992.000000       79992.000000
# mean    1067.146325     31306.107875          38.901873         -77.033117
# std     2124.003370       207.411012           0.023994           0.025657
# min       60.000000     31000.000000          38.797557         -77.361902
# 25%      389.000000     31202.000000          38.890493         -77.044780
# 50%      659.000000     31247.000000          38.900880         -77.032300
# 75%     1116.000000     31403.000000          38.912100         -77.017800
# max    86047.000000     32215.000000          39.123513         -76.925907
#
#        End station #      LATITUDE     LONGITUDE  REMOVAL_DATE  \
# count   80000.000000  79998.000000  79998.000000           0.0
# mean    31307.015925     38.900684    -77.032571           NaN
# std       204.277047      0.023394      0.025006           NaN
# min     31000.000000     38.797557    -77.359718           NaN
# 25%     31205.000000     38.890461    -77.044664           NaN
# 50%     31247.000000     38.900300    -77.032200           NaN
# 75%     31401.000000     38.909850    -77.017800           NaN
# max     32214.000000     39.123513    -76.913563           NaN
#
#        NUMBER_OF_BIKES
# count     79998.000000
# mean          6.852446
# std           5.973478
# min           0.000000
# 25%           2.000000
# 50%           5.000000
# 75%          11.000000
# max          26.000000

# %%
sstation_values = pd.DataFrame(sample_fin["Start station"].value_counts())
sstation_values.head(25).plot(kind="barh")
# plt.figure(figsize=(10,4))

# sstation = merge_table2_org_rename["Start station #"]
# sstation.head()

# %%
# graph members over time --- try splatter and bar
# plt.bar(sstation_values, sstation, marker="x", s=10)

# plt.title("Start Station")
# plt.ylabel("Usage")
# plt.xlabel("Start Station")
# plt.grid(True)

# # plt.savefig("Latitude_Humidity_Plot.png")
# plt.show()

# In [62]: ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1');
# In [63]: df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax);
# In [65]: df.plot.scatter(x='a', y='b', s=df['c']*200);
# In [66]: df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])

# In [67]: df['b'] = df['b'] + np.arange(1000)

# In [68]: df.plot.hexbin(x='a', y='b', gridsize=25)
# Out[68]: <matplotlib.axes._subplots.AxesSubplot at 0x7f20c0e53b70>    
    
sstation_values = pd.DataFrame(merge_table2_org_rename["Start station"].value_counts())
plt.figure(figsize=(16,4))
sstation_values.head(25).plot.bar()
# plot.scatter(x='a', y='b')

# .plot.area(stacked=False)
# .plot.area()
# plot.box()
# .plot.hist(alpha=0.5)
# plt.figure(figsize=(16,4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a1bd8325398b> in <module>()
#      20 # Out[68]: <matplotlib.axes._subplots.AxesSubplot at 0x7f20c0e53b70>
#      21
# ---> 22 sstation_values = pd.DataFrame(merge_table2_org_rename["Start station"].value_counts())
#      23 plt.figure(figsize=(16,4))
#      24 sstation_values.head(25).plot.bar()
#
# NameError: name 'merge_table2_org_rename' is not defined

# %%
# graph... heat map.. for usage points over time for stations

# %%
import gmaps

# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)
print(gkey)
# Out:
# AIzaSyBElBNjXQwe_Ed210gI9EpQ_Z31y8ej34o

# %%
sstation_values = pd.DataFrame(sample_fin.groupby("Start station")["Start station #"].value_counts())
sstation_values.head(2)

# sstation_values = (sample_fin["Start station #"].value_counts())
# sstation_values.head(10)
# Out:
#                                        Start station #
# Start station         Start station #
# 10th & E St NW        31256                        339
# 10th & Florida Ave NW 31120                        230

# %%
heatmapdata =  pd.DataFrame({"Start station": (sample_fin["Start station"]),
                             "Start station #" :(sample_fin["Start station #"]),
                             "Visits" : sstation_values,
                              "Start Station Lat": (sample_fin["Start Station Lat"]),
                              'Start Station Lng': (sample_fin["Start Station Lng"])
                                })

# (sample_fin["Start station #"].value_counts()),
heatmapdata.groupby(["Start station #"].value_counts())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-4ee1a9fb32c0> in <module>()
#       7
#       8 # (sample_fin["Start station #"].value_counts()),
# ----> 9 heatmapdata.groupby(["Start station #"].value_counts())
#
# AttributeError: 'list' object has no attribute 'value_counts'

# %%
# sstation_values.append(sample_fin["Start Station Lat"])
sample_fin.columns
# Out:
# Index(['Duration', 'Start date', 'End date', 'Start station #',
#        'Start station', 'Start Station Lat', 'Start Station Lng',
#        'End station #', 'End station', 'LATITUDE', 'LONGITUDE', 'Bike number',
#        'Member type', 'REMOVAL_DATE', 'NUMBER_OF_BIKES'],
#       dtype='object')

# %%
sstation_values.head(25).plot(kind="barh")

# %%
sample_fin.head()
# Out:
#    Duration           Start date             End date  Start station #  \
# 0      6023  2015-01-01 00:35:55  2015-01-01 02:16:19            31503
# 1       717  2015-01-01 01:04:42  2015-01-01 01:16:40            31252
# 2       654  2015-01-01 01:13:50  2015-01-01 01:24:44            31603
# 3       418  2015-01-01 01:17:19  2015-01-01 01:24:18            31104
# 4       110  2015-01-01 01:59:03  2015-01-01 02:00:54            31603
#
#                    Start station  Start Station Lat  Start Station Lng  \
# 0          Florida Ave & R St NW          38.912600         -77.013500
# 1  21st St & Pennsylvania Ave NW          38.901539         -77.046564
# 2                  1st & M St NE          38.905700         -77.005600
# 3    Adams Mill & Columbia Rd NW          38.922925         -77.042581
# 4                  1st & M St NE          38.905700         -77.005600
#
#    End station #                          End station   LATITUDE  LONGITUDE  \
# 0          31508  Gallaudet / 8th St & Florida Ave NE  38.905090 -76.994100
# 1          31258                     Lincoln Memorial  38.888251 -77.049426
# 2          31632                       15th & F St NE  38.897195 -76.983575
# 3          31119                 14th & Belmont St NW  38.921074 -77.031887
# 4          31603                        1st & M St NE  38.905700 -77.005600
#
#   Bike number Member type  REMOVAL_DATE  NUMBER_OF_BIKES
# 0      W00170      Member           NaN              1.0
# 1      W20243      Member           NaN              5.0
# 2      W20217      Member           NaN              0.0
# 3      W00645      Member           NaN              6.0
# 4      W20703      Member           NaN              6.0

# %%
# sample_fin_map = sample_fin.loc[[["Start station #", "Start Station Lat", "Start Station Lng"]],[(sample_fin["Start station #"].value_counts())]] 
# sample_fin_map
sample_fin_map = sample_fin.loc[(sample_fin["Start station #"].value_counts()),
                                ["Start station #", "Start Station Lat", "Start Station Lng"]]
# sample_fin_map

# %%
bike_stations_df = bike_location_df.set_index("TERMINAL_NUMBER")
bike_stations_df.head()

#merge the other way... to sum the numbers

# set_index

# sample_fin_map = sample_fin.loc[(sample_fin["Start station #"].value_counts()),
#                                 ["Start station #", "Start Station Lat", "Start Station Lng"]]
# Out:
#                   OBJECTID   ID                             ADDRESS  \
# TERMINAL_NUMBER
# 32210            223143627  434  Town Center Pkwy & Bowman Towne Dr
# 32211            223143628  435             Reston Regional Library
# 32212            223143629  436     New Dominion Pkwy & Fountain Dr
# 32213            223143630  437       Sunset Hills & Old Reston Ave
# 32214            223143631  438  Reston Town Center Transit Station
#
#                   LATITUDE  LONGITUDE INSTALLED LOCKED  INSTALL_DATE  \
# TERMINAL_NUMBER
# 32210            38.962524 -77.361902       YES     NO           NaN
# 32211            38.962095 -77.358815       YES     NO           NaN
# 32212            38.960574 -77.356324       YES     NO           NaN
# 32213            38.955079 -77.351649       YES     NO           NaN
# 32214            38.957037 -77.359718       YES     NO           NaN
#
#                  REMOVAL_DATE TEMPORARY_INSTALL  NUMBER_OF_BIKES  \
# TERMINAL_NUMBER
# 32210                     NaN                NO                8
# 32211                     NaN                NO                7
# 32212                     NaN                NO                4
# 32213                     NaN                NO               12
# 32214                     NaN                NO               14
#
#                  NUMBER_OF_EMPTY_DOCKS            X            Y  \
# TERMINAL_NUMBER
# 32210                                7  368634.8196  143908.1787
# 32211                                7  368902.1739  143859.4999
# 32212                               11  369117.4041  143689.8105
# 32213                                3  369520.2345  143078.2481
# 32214                                2  368821.7005  143298.3275
#
#                  SE_ANNO_CAD_DATA OWNER
# TERMINAL_NUMBER
# 32210                         NaN   NaN
#  20.0           31102.0          38.929464         -77.027822
#  2.0            31603.0          38.905700         -77.005600
#  12.0           31265.0          38.900930         -77.018677
#  10.0           31237.0          38.903827         -77.053485
#  38.0           31237.0          38.903827         -77.053485
#  11.0           31248.0          38.888767         -77.028580
# NaN                 NaN                NaN                NaN
# NaN                 NaN                NaN                NaN
# NaN                 NaN                NaN                NaN
# NaN                 NaN                NaN                NaN
# NaN                 NaN                NaN                NaN
#  2.0            31603.0          38.905700         -77.005600
# NaN                 NaN                NaN                NaN
# NaN                 NaN                NaN                NaN
# NaN                 NaN                NaN                NaN
#
# [422 rows x 3 columns]

# %%
bike_location_df.columns
# Out:
# Index(['OBJECTID', 'ID', 'ADDRESS', 'TERMINAL_NUMBER', 'LATITUDE', 'LONGITUDE',
#        'INSTALLED', 'LOCKED', 'INSTALL_DATE', 'REMOVAL_DATE',
#        'TEMPORARY_INSTALL', 'NUMBER_OF_BIKES', 'NUMBER_OF_EMPTY_DOCKS', 'X',
#        'Y', 'SE_ANNO_CAD_DATA', 'OWNER'],
#       dtype='object')

# %%
# sample_fin[["Start Station Lat", "Start Station Lng"]]
# sample_fin["Start station #"].value_counts()

# %%
# Store latitude and longitude in locations
locations = sample_fin_map[["Start Station Lat", "Start Station Lng"]]
# locations = airport_df[["Lat", "Lng"]]

# Fill NaN values and convert to float
# rating = airport_df["Airport Rating"].astype(float)

rating = sample_fin_map.index.astype(float)

# %%
fig = gmaps.figure(map_type="HYBRID")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10,
                                 point_radius=.0015)

fig.add_layer(heat_layer)
fig
# Out:
# ---------------------------------------------------------------------------
# InvalidPointException                     Traceback (most recent call last)
# <ipython-input-48-7a72c06ec550> in <module>()
#       4 heat_layer = gmaps.heatmap_layer(locations, weights=rating,
#       5                                  dissipating=False, max_intensity=10,
# ----> 6                                  point_radius=.0015)
#       7
#       8 fig.add_layer(heat_layer)
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\gmaps\heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     267     )
#     268     if is_weighted:
# --> 269         return WeightedHeatmap(**widget_args)
#     270     else:
#     271         return Heatmap(**widget_args)
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\ipywidgets\widgets\widget.py in __init__(self, **kwargs)
#     409         """Public constructor"""
#     410         self._model_id = kwargs.pop('model_id', None)
# --> 411         super(Widget, self).__init__(**kwargs)
#     412
#     413         Widget._call_widget_constructed(self)
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\traitlets\traitlets.py in __init__(self, *args, **kwargs)
#     995             for key, value in kwargs.items():
#     996                 if self.has_trait(key):
# --> 997                     setattr(self, key, value)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\traitlets\traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\gmaps\geotraitlets.py in validate(self, obj, value)
#      25         for location in locations_as_list:
#      26             latitude, longitude = location
# ---> 27             _validate_latitude(latitude)
#      28             _validate_longitude(longitude)
#      29         return super(LocationArray, self).validate(obj, locations_as_list)
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\gmaps\geotraitlets.py in _validate_latitude(latitude)
#     296         raise InvalidPointException(
#     297             '{} is not a valid latitude. '
# --> 298             'Latitudes must lie between -90 and 90.'.format(latitude)
#     299         )
#     300
#
# InvalidPointException: nan is not a valid latitude. Latitudes must lie between -90 and 90.

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations,  weights=rating,
                                 dissipating=False, max_intensity=10,
                                 point_radius=.0010)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# ---------------------------------------------------------------------------
# InvalidPointException                     Traceback (most recent call last)
# <ipython-input-49-181429ac8434> in <module>()
#       5 heat_layer = gmaps.heatmap_layer(locations,  weights=rating,
#       6                                  dissipating=False, max_intensity=10,
# ----> 7                                  point_radius=.0010)
#       8
#       9
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\gmaps\heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     267     )
#     268     if is_weighted:
# --> 269         return WeightedHeatmap(**widget_args)
#     270     else:
#     271         return Heatmap(**widget_args)
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\ipywidgets\widgets\widget.py in __init__(self, **kwargs)
#     409         """Public constructor"""
#     410         self._model_id = kwargs.pop('model_id', None)
# --> 411         super(Widget, self).__init__(**kwargs)
#     412
#     413         Widget._call_widget_constructed(self)
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\traitlets\traitlets.py in __init__(self, *args, **kwargs)
#     995             for key, value in kwargs.items():
#     996                 if self.has_trait(key):
# --> 997                     setattr(self, key, value)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\traitlets\traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\gmaps\geotraitlets.py in validate(self, obj, value)
#      25         for location in locations_as_list:
#      26             latitude, longitude = location
# ---> 27             _validate_latitude(latitude)
#      28             _validate_longitude(longitude)
#      29         return super(LocationArray, self).validate(obj, locations_as_list)
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\gmaps\geotraitlets.py in _validate_latitude(latitude)
#     296         raise InvalidPointException(
#     297             '{} is not a valid latitude. '
# --> 298             'Latitudes must lie between -90 and 90.'.format(latitude)
#     299         )
#     300
#
# InvalidPointException: nan is not a valid latitude. Latitudes must lie between -90 and 90.

# %%
# do bins histo over for each year

# %%
# sstation_values3 = pd.DataFrame(sample_fin.groupby("Start station")["Start station #"].value_counts())
# sstation_values3.head(25)

# ss3_sort =sstation_values3.sort_values(["Start station #"]) ascending=False)

# sstation_values = pd.DataFrame({"Visits" : [sample_fin["Start station #"].value_counts()])
# sstation_values.head()

# total_players_df = pd.DataFrame({"Total Players":[purchase_data["SN"].nunique()]})
# total_players_df
