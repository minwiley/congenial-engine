# %%
# dependencies
import random
import pandas as pd
import requests
import json
import numpy as np
import glob

# %%
file_15Q1 = "all_files/2015Q1-capitalbikeshare-tripdata.csv"
data_15Q1 = pd.read_csv(file_15Q1,index_col=None, header=0)
data_15Q1.head()
# Out:
#    Duration           Start date             End date  Start station number  \
# 0      2389  2015-01-01 00:02:44  2015-01-01 00:42:33                 31271
# 1      2394  2015-01-01 00:02:46  2015-01-01 00:42:41                 31271
# 2       468  2015-01-01 00:04:32  2015-01-01 00:12:20                 31204
# 3       348  2015-01-01 00:07:18  2015-01-01 00:13:06                 31602
# 4       980  2015-01-01 00:09:39  2015-01-01 00:26:00                 31247
#
#                       Start station  End station number  \
# 0  Constitution Ave & 2nd St NW/DOL               31254
# 1  Constitution Ave & 2nd St NW/DOL               31254
# 2                    20th & E St NW               31234
# 3           Park Rd & Holmead Pl NW               31117
# 4         Jefferson Dr & 14th St SW               31241
#
#                      End station Bike number Member type
# 0                 15th & K St NW      W01140      Casual
# ...

# %%
location_file = "all_files/location.csv"
location_df = pd.read_csv(location_file,index_col=None, header=0)
location_df.head(3)
# Out:
#     OBJECTID   ID                             ADDRESS  TERMINAL_NUMBER  \
# 0  223143627  434  Town Center Pkwy & Bowman Towne Dr            32210
# 1  223143628  435             Reston Regional Library            32211
# 2  223143629  436     New Dominion Pkwy & Fountain Dr            32212
#
#     LATITUDE  LONGITUDE INSTALLED LOCKED  INSTALL_DATE  REMOVAL_DATE  \
# 0  38.962524 -77.361902       YES     NO           NaN           NaN
# 1  38.962095 -77.358815       YES     NO           NaN           NaN
# 2  38.960574 -77.356324       YES     NO           NaN           NaN
#
#   TEMPORARY_INSTALL  NUMBER_OF_BIKES  NUMBER_OF_EMPTY_DOCKS            X  \
# 0                NO                8                      7  368634.8196
# 1                NO                7                      7  368902.1739
# 2                NO                4                     11  369117.4041
#
#              Y  SE_ANNO_CAD_DATA OWNER
# 0  143908.1787               NaN   NaN
# ...

# %%
len(data_15Q1["Start station number"].unique())
# Out:
# 347

# %%
len(location_df["TERMINAL_NUMBER"].unique())
# Out:
# 517

# %%
len(data_15Q1["End station number"].unique())
# Out:
# 348

# %%
location_df["TERMINAL_NUMBER"]
renamed_df = location_df.rename(columns={"TERMINAL_NUMBER":"Start station number"})
renamed_df.head()
# Out:
#     OBJECTID   ID                             ADDRESS  Start station number  \
# 0  223143627  434  Town Center Pkwy & Bowman Towne Dr                 32210
# 1  223143628  435             Reston Regional Library                 32211
# 2  223143629  436     New Dominion Pkwy & Fountain Dr                 32212
# 3  223143630  437       Sunset Hills & Old Reston Ave                 32213
# 4  223143631  438  Reston Town Center Transit Station                 32214
#
#     LATITUDE  LONGITUDE INSTALLED LOCKED  INSTALL_DATE  REMOVAL_DATE  \
# 0  38.962524 -77.361902       YES     NO           NaN           NaN
# 1  38.962095 -77.358815       YES     NO           NaN           NaN
# 2  38.960574 -77.356324       YES     NO           NaN           NaN
# 3  38.955079 -77.351649       YES     NO           NaN           NaN
# 4  38.957037 -77.359718       YES     NO           NaN           NaN
#
#   TEMPORARY_INSTALL  NUMBER_OF_BIKES  NUMBER_OF_EMPTY_DOCKS            X  \
# ...

# %%
merge_table = pd.merge(data_15Q1, renamed_df, on="Start station number", how="left")
merge_table
# Out:
#         Duration           Start date             End date  \
# 0           2389  2015-01-01 00:02:44  2015-01-01 00:42:33
# 1           2394  2015-01-01 00:02:46  2015-01-01 00:42:41
# 2            468  2015-01-01 00:04:32  2015-01-01 00:12:20
# 3            348  2015-01-01 00:07:18  2015-01-01 00:13:06
# 4            980  2015-01-01 00:09:39  2015-01-01 00:26:00
# 5            932  2015-01-01 00:10:33  2015-01-01 00:26:06
# 6            387  2015-01-01 00:12:26  2015-01-01 00:18:53
# 7            321  2015-01-01 00:13:01  2015-01-01 00:18:22
# 8            294  2015-01-01 00:16:52  2015-01-01 00:21:47
# 9           2646  2015-01-01 00:17:03  2015-01-01 01:01:10
# 10           607  2015-01-01 00:18:20  2015-01-01 00:28:27
# 11           670  2015-01-01 00:19:42  2015-01-01 00:30:52
# 12           544  2015-01-01 00:20:06  2015-01-01 00:29:10
# 13           631  2015-01-01 00:20:08  2015-01-01 00:30:40
# 14           484  2015-01-01 00:20:19  2015-01-01 00:28:23
# ...

# %%
merge_table.columns
# Out:
# Index(['Duration', 'Start date', 'End date', 'Start station number',
#        'Start station', 'End station number', 'End station', 'Bike number',
#        'Member type', 'OBJECTID', 'ID', 'ADDRESS', 'LATITUDE', 'LONGITUDE',
#        'INSTALLED', 'LOCKED', 'INSTALL_DATE', 'REMOVAL_DATE',
#        'TEMPORARY_INSTALL', 'NUMBER_OF_BIKES', 'NUMBER_OF_EMPTY_DOCKS', 'X',
#        'Y', 'SE_ANNO_CAD_DATA', 'OWNER'],
#       dtype='object')

# %%
merge_table_some = merge_table[['Duration', 'Start date', 'End date', 'Start station number', 
                                'Start station', 'End station number', 'End station', 'Bike number',
                                'Member type', 'ADDRESS', 'LATITUDE', 'LONGITUDE']]
merge_table_some
# Out:
#         Duration           Start date             End date  \
# 0           2389  2015-01-01 00:02:44  2015-01-01 00:42:33
# 1           2394  2015-01-01 00:02:46  2015-01-01 00:42:41
# 2            468  2015-01-01 00:04:32  2015-01-01 00:12:20
# 3            348  2015-01-01 00:07:18  2015-01-01 00:13:06
# 4            980  2015-01-01 00:09:39  2015-01-01 00:26:00
# 5            932  2015-01-01 00:10:33  2015-01-01 00:26:06
# 6            387  2015-01-01 00:12:26  2015-01-01 00:18:53
# 7            321  2015-01-01 00:13:01  2015-01-01 00:18:22
# 8            294  2015-01-01 00:16:52  2015-01-01 00:21:47
# 9           2646  2015-01-01 00:17:03  2015-01-01 01:01:10
# 10           607  2015-01-01 00:18:20  2015-01-01 00:28:27
# 11           670  2015-01-01 00:19:42  2015-01-01 00:30:52
# 12           544  2015-01-01 00:20:06  2015-01-01 00:29:10
# 13           631  2015-01-01 00:20:08  2015-01-01 00:30:40
# 14           484  2015-01-01 00:20:19  2015-01-01 00:28:23
# ...

# %%
renamed_df2 = renamed_df.rename(columns={"Start station number" : "End station number"})
renamed_df2.head()


merge_table2 = pd.merge(merge_table_some, renamed_df2, on="End station number", how="left")
merge_table2
# Out:
#         Duration           Start date             End date  \
# 0           2389  2015-01-01 00:02:44  2015-01-01 00:42:33
# 1           2394  2015-01-01 00:02:46  2015-01-01 00:42:41
# 2            468  2015-01-01 00:04:32  2015-01-01 00:12:20
# 3            348  2015-01-01 00:07:18  2015-01-01 00:13:06
# 4            980  2015-01-01 00:09:39  2015-01-01 00:26:00
# 5            932  2015-01-01 00:10:33  2015-01-01 00:26:06
# 6            387  2015-01-01 00:12:26  2015-01-01 00:18:53
# 7            321  2015-01-01 00:13:01  2015-01-01 00:18:22
# 8            294  2015-01-01 00:16:52  2015-01-01 00:21:47
# 9           2646  2015-01-01 00:17:03  2015-01-01 01:01:10
# 10           607  2015-01-01 00:18:20  2015-01-01 00:28:27
# 11           670  2015-01-01 00:19:42  2015-01-01 00:30:52
# 12           544  2015-01-01 00:20:06  2015-01-01 00:29:10
# 13           631  2015-01-01 00:20:08  2015-01-01 00:30:40
# 14           484  2015-01-01 00:20:19  2015-01-01 00:28:23
# ...

# %%
merge_table2.columns
# Out:
# Index(['Duration', 'Start date', 'End date', 'Start station number',
#        'Start station', 'End station number', 'End station', 'Bike number',
#        'Member type', 'ADDRESS_x', 'LATITUDE_x', 'LONGITUDE_x', 'OBJECTID',
#        'ID', 'ADDRESS_y', 'LATITUDE_y', 'LONGITUDE_y', 'INSTALLED', 'LOCKED',
#        'INSTALL_DATE', 'REMOVAL_DATE', 'TEMPORARY_INSTALL', 'NUMBER_OF_BIKES',
#        'NUMBER_OF_EMPTY_DOCKS', 'X', 'Y', 'SE_ANNO_CAD_DATA', 'OWNER'],
#       dtype='object')

# %%
merge_table_some2 = merge_table2[['Duration', 'Start date', 'End date', 'Start station number',
       'Start station', 'End station number', 'End station', 'Bike number',
       'Member type', 'ADDRESS_x', 'LATITUDE_x', 'LONGITUDE_x', 'ADDRESS_y', 'LATITUDE_y', 'LONGITUDE_y', 'NUMBER_OF_BIKES']]
merge_table_some2
# Out:
#         Duration           Start date             End date  \
# 0           2389  2015-01-01 00:02:44  2015-01-01 00:42:33
# 1           2394  2015-01-01 00:02:46  2015-01-01 00:42:41
# 2            468  2015-01-01 00:04:32  2015-01-01 00:12:20
# 3            348  2015-01-01 00:07:18  2015-01-01 00:13:06
# 4            980  2015-01-01 00:09:39  2015-01-01 00:26:00
# 5            932  2015-01-01 00:10:33  2015-01-01 00:26:06
# 6            387  2015-01-01 00:12:26  2015-01-01 00:18:53
# 7            321  2015-01-01 00:13:01  2015-01-01 00:18:22
# 8            294  2015-01-01 00:16:52  2015-01-01 00:21:47
# 9           2646  2015-01-01 00:17:03  2015-01-01 01:01:10
# 10           607  2015-01-01 00:18:20  2015-01-01 00:28:27
# 11           670  2015-01-01 00:19:42  2015-01-01 00:30:52
# 12           544  2015-01-01 00:20:06  2015-01-01 00:29:10
# 13           631  2015-01-01 00:20:08  2015-01-01 00:30:40
# 14           484  2015-01-01 00:20:19  2015-01-01 00:28:23
# ...

# %%
location_df.loc[location_df.TERMINAL_NUMBER==32214, 'LATITUDE' : 'LONGITUDE']
# Out:
#     LATITUDE  LONGITUDE
# 4  38.957037 -77.359718

# %%
# location_df.loc[:, [ 'TERMINAL_NUMBER', 'LATITUDE' , 'LONGITUDE']]

# %%
# terminal_location = location_df.set_index("TERMINAL_NUMBER")
# terminal_location.head()

# location_df.loc[:, [ 'TERMINAL_NUMBER', 'LATITUDE' , 'LONGITUDE']]

# adding 4 columns - end and start stations lat and long
data_15Q1['end_station_lat'] = ''
data_15Q1['end_station_lon'] = ''

data_15Q1['start_station_lat'] =''
data_15Q1['start_station_lon'] =''

data_15Q1.head(3)
# Out:
#    Duration           Start date             End date  Start station number  \
# 0      2389  2015-01-01 00:02:44  2015-01-01 00:42:33                 31271
# 1      2394  2015-01-01 00:02:46  2015-01-01 00:42:41                 31271
# 2       468  2015-01-01 00:04:32  2015-01-01 00:12:20                 31204
#
#                       Start station  End station number  \
# 0  Constitution Ave & 2nd St NW/DOL               31254
# 1  Constitution Ave & 2nd St NW/DOL               31254
# 2                    20th & E St NW               31234
#
#                      End station Bike number Member type end_station_lat  \
# 0                 15th & K St NW      W01140      Casual
# 1                 15th & K St NW      W00612      Casual
# 2  20th & O St NW / Dupont South      W01226      Member
#
#   end_station_lon start_station_lat start_station_lon
# 0
# 1
# 2

# %%
if location_df.loc[location_df.TERMINAL_NUMBER==(data_15Q1['Start station number']):
   location_df.LATITUDE = data_15Q1['start_station_lat']
print(data_15Q1['start_station_lat'])
# Out:
#   File "<ipython-input-179-87656cf81ba6>", line 2
#     location_df.LATITUDE = data_15Q1['start_station_lat']
#                          ^
# SyntaxError: invalid syntax

# %%
if location_df.loc[location_df.TERMINAL_NUMBER==(data_15Q1['Start station number']):
                   location_df.LATITUDE = data_15Q1['start_station_lat']
                   print(data_15Q1['start_station_lat'])



# logs_df['EmployeeName'] = logs_df.EmployeeID.map(employees)

# lat = []
# lng = []
dock_stations = []
counter = 0

for dock in dock_stations:
    if location_df.loc[location_df.TERMINAL_NUMBER==(data_15Q1['Start station number']):
                       data_15Q1['start_station_lat'].append(location_df.LATITUDE)
#                        location_df.LONGITUDE = data_15Q1['start_station_lon']
#                        counter += 0
 data_15Q1['start_station_lat']
                       
                       
# 32214, 'LATITUDE' : 'LONGITUDE']: 
    
    
# if location_df.loc[location_df.TERMINAL_NUMBER== (data_15Q1('Start station number')), 'LATITUDE' : 'LONGITUDE']:
# Out:
#   File "<ipython-input-176-0b407368368c>", line 13
#     data_15Q1['start_station_lat']
#             ^
# SyntaxError: invalid syntax

# %%
stations = []
counter = 0

for stations in stations:
    if (location_df["Terminal_Number"]) = (data15q1["Start_Station"]):
        location_df["Latitude"] = data15q1["Start_Station_Lat"]
        print(data15q1["Start_Station_Lat"])
        location_df["Longitude"] = data15q1["Start_Station_Lng"]
        print(data15q1["Start_Station_Lng"])
        counter += 1
    else:
        data15q1["Start_Station_Lat"] = NaN
        data15q1["Start_Station_Lng"] = NaN


# 	if location_df["Terminal_Number"] = data15q1["End_Station"]:
# 		location_df["Latitude"] = data15q1["end_Station_Lat"]
# 		print(data15q1["Start_Station_Lat"])
# 		location_df["Longitude"] = data15q1["end_Station_Lng"]
# 		print(data15q1["Start_Station_Lng"])

# 		counter += 1

# %%
# terminal_location 
# location_df[location_df.TERMINAL_NUMBER == '32214']

# %%
# terminal_32212 = location_df.loc[ "32212", "LATITUDE", "LONGITUDE"]
# terminal_32212

# terminal_find = location_df.loc[location_df["TERMINAL_NUMBER"] == "32212"]


# # [ "LATITUDE", "LONGITUDE"]]

# %%
# if location_df['TERMINAL_NUMBER'] = "32212"
#     location_df[LATITUDE] = 
#     location_df[LONGITUDE] = 

terminal_find = location_df.loc[location_df["TERMINAL_NUMBER"] == "32212"


# # [ "LATITUDE", "LONGITUDE"]]
                               
                               
# location_df = location_df.set_index("TERMINAL_NUMBER")
# location_df.head()                         
                               
# terminal_find = location_df.loc[(('TERMINAL_NUMBER') == ("32211")),'LATITUDE','LONGITUDE']
# print(terminal_find)
                              
# # Grab the data contained within the "Berry" row and the "Phone Number" column
# berry_phone = df.loc["Berry", "Phone Number"]
# print("Using Loc: " + berry_phone)

# also_berry_phone = df.iloc[1, 2]
# print("Using Iloc: " + also_berry_phone)
# Out:
#   File "<ipython-input-111-c0752dfdde22>", line 24
#     # print("Using Iloc: " + also_berry_phone)
#                                               ^
# SyntaxError: unexpected EOF while parsing

# %%
data_15Q1.columns
# Out:
# Index(['Duration', 'Start date', 'End date', 'Start station number',
#        'Start station', 'End station number', 'End station', 'Bike number',
#        'Member type'],
#       dtype='object')

# %%
# Out:
#         Duration           Start date             End date  \
# 0           2389  2015-01-01 00:02:44  2015-01-01 00:42:33
# 1           2394  2015-01-01 00:02:46  2015-01-01 00:42:41
# 2            468  2015-01-01 00:04:32  2015-01-01 00:12:20
# 3            348  2015-01-01 00:07:18  2015-01-01 00:13:06
# 4            980  2015-01-01 00:09:39  2015-01-01 00:26:00
# 5            932  2015-01-01 00:10:33  2015-01-01 00:26:06
# 6            387  2015-01-01 00:12:26  2015-01-01 00:18:53
# 7            321  2015-01-01 00:13:01  2015-01-01 00:18:22
# 8            294  2015-01-01 00:16:52  2015-01-01 00:21:47
# 9           2646  2015-01-01 00:17:03  2015-01-01 01:01:10
# 10           607  2015-01-01 00:18:20  2015-01-01 00:28:27
# 11           670  2015-01-01 00:19:42  2015-01-01 00:30:52
# 12           544  2015-01-01 00:20:06  2015-01-01 00:29:10
# 13           631  2015-01-01 00:20:08  2015-01-01 00:30:40
# 14           484  2015-01-01 00:20:19  2015-01-01 00:28:23
# ...

# %%
location_df.columns
# Out:
# Index(['OBJECTID', 'ID', 'ADDRESS', 'TERMINAL_NUMBER', 'LATITUDE', 'LONGITUDE',
#        'INSTALLED', 'LOCKED', 'INSTALL_DATE', 'REMOVAL_DATE',
#        'TEMPORARY_INSTALL', 'NUMBER_OF_BIKES', 'NUMBER_OF_EMPTY_DOCKS', 'X',
#        'Y', 'SE_ANNO_CAD_DATA', 'OWNER'],
#       dtype='object')

# %%
# # loc_df['LATITUDE']
# loc_df['LONGITUDE']

# %%
lng_dock = location_df['LONGITUDE']
lat_dock = location_df['LATITUDE']
dock_station = location_df['TERMINAL_NUMBER']


dock_lat_lng = pd.DataFrame({"Dock Station": dock_station, "Dock Lat" : lat_dock, " Dock Lng" : lng_dock})
dock_lat_lng.head()
# Out:
#    Dock Station   Dock Lat   Dock Lng
# 0         32210  38.962524 -77.361902
# 1         32211  38.962095 -77.358815
# 2         32212  38.960574 -77.356324
# 3         32213  38.955079 -77.351649
# 4         32214  38.957037 -77.359718

# %%
if dock_lat_lng["Dock Station"] = data_15Q1["Start station number"]:
    print(dock_lat_lng[Dock Lat])
# Out:
#   File "<ipython-input-185-9c10bb92f92f>", line 1
#     if dock_lat_lng["Dock Station"] = data_15Q1["Start station number"]:
#                                     ^
# SyntaxError: invalid syntax

# %%
# for loop to loop through 2 csvs
# conditionals if terminal_number in loc_df = start station number in data_15Q1
# then add lat and long from loc_df into data_15q1

data_15Q1['start_station_lat'] 
data_15Q1['end_station_lat'] 

data_15Q1['end_station_lon'] 
data_15Q1['start_station_lon'] 

loc_df['LATITUDE']
loc_df['LONGITUDE']

for dock in dock_stations:
    if loc_df['TERMINAL_NUMBER'] = data_15Q1['Start station number']:
        lat.append
        lng.append
