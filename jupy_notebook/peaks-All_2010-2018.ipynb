# %%
# dependencies
import random
import pandas as pd
import requests
import json
import numpy as np
import glob
import matplotlib.pyplot as plt
import json

# %%
filename = "All_files_w_lat&lng.csv"
# filename = "Capitalbikesharedata_all.csv"
df = pd.read_csv(filename, index_col=None, header=0, low_memory=False)
df.head(2)
# Out:
#    Duration           Start date             End date  Start station #  \
# 0      1012  2010-09-20 11:27:04  2010-09-20 11:43:56            31208
# 1        61  2010-09-20 11:41:22  2010-09-20 11:42:23            31209
#
#               Start station  Start Station Lat  Start Station Lng  \
# 0  M St & New Jersey Ave SE            38.8763           -77.0037
# 1            1st & N St  SE            38.8743           -77.0057
#
#    End station #     End station  LATITUDE  LONGITUDE Bike number Member type  \
# 0          31108   4th & M St SW   38.8767   -77.0178      W00742      Member
# 1          31209  1st & N St  SE   38.8743   -77.0057      W00032      Member
#
#   LOCKED  INSTALL_DATE  REMOVAL_DATE  NUMBER_OF_BIKES
# 0     NO           NaN           NaN              5.0
# 1     NO           NaN           NaN              1.0

# %%
df.columns
# Out:
# Index(['Duration', 'Start date', 'End date', 'Start station #',
#        'Start station', 'Start Station Lat', 'Start Station Lng',
#        'End station #', 'End station', 'LATITUDE', 'LONGITUDE', 'Bike number',
#        'Member type', 'LOCKED', 'INSTALL_DATE', 'REMOVAL_DATE',
#        'NUMBER_OF_BIKES'],
#       dtype='object')

# %%
df = df.rename(columns={'Duration': 'Duration', 
                        'Start date': 'Start date', 
                        'End date': 'End date', 
                        'Start station #': 'Start station number',
                        'Start station': 'Start station', 
                        'Start Station Lat': 'Start station lat', 
                        'Start Station Lng': 'Start station lng',
                        'End station #': 'End station number', 
                        'End station': 'End station', 
                        'LATITUDE': 'End station lat', 
                        'LONGITUDE': 'End station lng', 
                        'Bike number': 'Bike number', 
                        'NUMBER_OF_BIKES': 'number of bikes',
                        'Member type': 'Member type'
                       })
df.columns
# Out:
# Index(['Duration', 'Start date', 'End date', 'Start station number',
#        'Start station', 'Start station lat', 'Start station lng',
#        'End station number', 'End station', 'End station lat',
#        'End station lng', 'Bike number', 'Member type', 'LOCKED',
#        'INSTALL_DATE', 'REMOVAL_DATE', 'number of bikes'],
#       dtype='object')

# %%
df = df[['Duration', 'Start date', 'End date', 'Start station number','Start station', 'Start station lat', 
         'Start station lng', 'End station number', 'End station', 'End station lat', 'End station lng', 
         'Bike number', 'number of bikes','Member type']]
df.head(2)
# Out:
#    Duration           Start date             End date  Start station number  \
# 0      1012  2010-09-20 11:27:04  2010-09-20 11:43:56                 31208
# 1        61  2010-09-20 11:41:22  2010-09-20 11:42:23                 31209
#
#               Start station  Start station lat  Start station lng  \
# 0  M St & New Jersey Ave SE            38.8763           -77.0037
# 1            1st & N St  SE            38.8743           -77.0057
#
#    End station number     End station  End station lat  End station lng  \
# 0               31108   4th & M St SW          38.8767         -77.0178
# 1               31209  1st & N St  SE          38.8743         -77.0057
#
#   Bike number  number of bikes Member type
# 0      W00742              5.0      Member
# 1      W00032              1.0      Member

# %%
df['Year'] = df["End date"].str[:4]
df['Month'] = df['End date'].str[5:7]
df['Date'] = df["End date"].str[:10]
df['Time_Hr'] = df["End date"].str[11:13]
df
# Out:
#           End station lng Bike number  number of bikes Member type  Year  \
# 0              -77.017800      W00742              5.0      Member  2010
# 1              -77.005700      W00032              1.0      Member  2010
# 2              -77.042900      W00993              2.0      Member  2010
# 3              -77.031500      W00344              0.0      Member  2010
# 4              -77.034438      W00883             13.0      Member  2010
# 5              -77.044400      W00850             13.0      Member  2010
# 6              -77.032200      W00804              0.0      Member  2010
# 7              -77.003700      W01084              6.0      Member  2010
# 8              -76.976900      W00812              1.0      Member  2010
# 9              -77.005600      W00803              6.0      Member  2010
# 10             -77.044400      W00256             13.0      Member  2010
# 11             -77.005600      W01023              6.0      Member  2010
# 12             -77.031500      W00472              0.0      Member  2010
# 13             -77.036536      W00685              1.0      Member  2010
# 14             -77.042900      W00930              2.0      Member  2010
# 15             -77.042581      W00685              3.0      Member  2010
# 16             -77.022200      W00476              0.0      Member  2010
# 17             -77.005600      W00955              6.0      Member  2010
# 18             -77.049593      W01066              3.0      Member  2010
# 19             -77.044400      W00824             13.0      Member  2010
# 20             -77.044400      W00883             13.0      Member  2010
# 21             -77.022200      W01029              0.0      Member  2010
# 22             -77.051514      W00821              8.0      Member  2010
# 23             -77.042900      W00833              2.0      Member  2010
# 24             -77.051520      W01123              4.0      Member  2010
# 25             -77.051520      W01034              4.0      Member  2010
# 26             -77.042581      W00796              3.0      Member  2010
# 27             -77.019027      W00883              7.0      Member  2010
# 28             -77.032085      W00796             15.0      Member  2010
# 29             -77.049800      W00764             11.0      Member  2010
# ...                   ...         ...              ...         ...   ...
# 21533500       -77.031500      W00922              0.0      Member  2018
# 21533501       -77.075104      W20670              3.0      Member  2018
# 21533502       -77.027137      W23221              6.0      Member  2018
# 21533503       -77.002130      W21031              1.0      Casual  2018
# 21533504       -76.996806       70203              0.0      Member  2018
# 21533505       -77.022270      W20468              1.0      Casual  2018
# 21533506       -77.019027      W01058              7.0      Member  2018
# 21533507       -77.038180      W20320              2.0      Member  2018
# 21533508       -77.032800      W22469              8.0      Member  2018
# 21533509       -76.995397      W01319              3.0      Casual  2018
# 21533510       -76.995397      W23369              3.0      Casual  2018
# 21533511       -77.010837      W00203              3.0      Casual  2018
# 21533512       -77.010837      W20994              3.0      Casual  2018
# 21533513       -77.027140      W20719              0.0      Member  2018
# 21533514       -77.032200      W22146              0.0      Member  2018
# 21533515       -77.027140      W23068              0.0      Member  2018
# 21533516       -77.032200      W20730              0.0      Member  2018
# 21533517       -77.053485      W23698              2.0      Member  2018
# 21533518       -77.038180      W21356              2.0      Member  2018
# 21533519       -77.120776      W21255             14.0      Member  2018
# 21533520       -77.059821      W00788              6.0      Member  2018
# 21533521       -77.113454      W22471             12.0      Member  2018
# 21533522       -77.025672      W00844              6.0      Member  2018
# 21533523       -77.022155      W01110              0.0      Member  2018
# 21533524       -77.038359      W21585              9.0      Member  2018
# 21533525       -76.995500      W21858              9.0      Member  2018
# 21533526       -77.019027      W23151              7.0      Member  2018
# 21533527       -77.051084      W20163              5.0      Casual  2018
# 21533528       -77.004950      W22096              3.0      Member  2018
# 21533529       -77.065149      W22315             16.0      Member  2018
#
#          Month        Date Time_Hr
# 0           09  2010-09-20      11
# 1           09  2010-09-20      11
# 2           09  2010-09-20      12
# 3           09  2010-09-20      12
# 4           09  2010-09-20      12
# 5           09  2010-09-20      12
# 6           09  2010-09-20      12
# 7           09  2010-09-20      12
# 8           09  2010-09-20      13
# 9           09  2010-09-20      12
# 10          09  2010-09-20      12
# 11          09  2010-09-20      12
# 12          09  2010-09-20      12
# 13          09  2010-09-20      12
# 14          09  2010-09-20      13
# 15          09  2010-09-20      12
# 16          09  2010-09-20      12
# 17          09  2010-09-20      13
# 18          09  2010-09-20      12
# 19          09  2010-09-20      13
# 20          09  2010-09-20      13
# 21          09  2010-09-20      13
# 22          09  2010-09-20      13
# 23          09  2010-09-20      13
# 24          09  2010-09-20      13
# 25          09  2010-09-20      13
# 26          09  2010-09-20      13
# 27          09  2010-09-20      13
# 28          09  2010-09-20      13
# 29          09  2010-09-20      14
# ...        ...         ...     ...
# 21533500    09  2018-09-30      23
# 21533501    09  2018-09-30      23
# 21533502    09  2018-09-30      23
# 21533503    09  2018-09-30      23
# 21533504    10  2018-10-01      00
# 21533505    09  2018-09-30      23
# 21533506    09  2018-09-30      23
# 21533507    09  2018-09-30      23
# 21533508    09  2018-09-30      23
# 21533509    10  2018-10-01      00
# 21533510    10  2018-10-01      00
# 21533511    10  2018-10-01      00
# 21533512    10  2018-10-01      00
# 21533513    10  2018-10-01      00
# 21533514    09  2018-09-30      23
# 21533515    10  2018-10-01      00
# 21533516    09  2018-09-30      23
# 21533517    10  2018-10-01      00
# 21533518    09  2018-09-30      23
# 21533519    09  2018-09-30      23
# 21533520    10  2018-10-01      00
# 21533521    10  2018-10-01      05
# 21533522    10  2018-10-01      00
# 21533523    09  2018-09-30      23
# 21533524    10  2018-10-01      00
# 21533525    10  2018-10-01      00
# 21533526    10  2018-10-01      00
# 21533527    10  2018-10-01      00
# 21533528    10  2018-10-01      00
# 21533529    10  2018-10-01      00
#
# [21533530 rows x 18 columns]

# %%
df.columns
df = df[['Duration', 'Start date', 'End date', 'Year', 'Month', 'Date', 'Time_Hr','Start station number','Start station', 'Start station lat', 
         'Start station lng', 'End station number', 'End station', 'End station lat', 'End station lng', 
         'Bike number', 'number of bikes','Member type']]
df.head(2)
# Out:
#    Duration           Start date             End date  Year Month        Date  \
# 0      1012  2010-09-20 11:27:04  2010-09-20 11:43:56  2010    09  2010-09-20
# 1        61  2010-09-20 11:41:22  2010-09-20 11:42:23  2010    09  2010-09-20
#
#   Time_Hr  Start station number             Start station  Start station lat  \
# 0      11                 31208  M St & New Jersey Ave SE            38.8763
# 1      11                 31209            1st & N St  SE            38.8743
#
#    Start station lng  End station number     End station  End station lat  \
# 0           -77.0037               31108   4th & M St SW          38.8767
# 1           -77.0057               31209  1st & N St  SE          38.8743
#
#    End station lng Bike number  number of bikes Member type
# 0         -77.0178      W00742              5.0      Member
# 1         -77.0057      W00032              1.0      Member

# %%
df.to_csv("AllYrs_lat&lng_time.csv", index=False)

# %%
df['End station number'].value_counts()
# Out:
# 31623    470684
# 31200    469547
# 31201    349326
# 31258    340369
# 31247    322543
# 31101    270003
# 31229    250990
# 31214    246995
# 31613    238335
# 31228    236639
# 31241    236635
# 31203    217333
# 31248    215319
# 31624    213112
# 31600    211773
# 31249    208208
# 31202    198914
# 31232    198787
# 31222    191950
# 31110    191625
# 31603    190903
# 31212    189989
# 31213    181423
# 31230    178447
# 31243    175616
# 31246    175513
# 31104    173056
# 31237    165901
# 31225    164612
# 31108    163359
#           ...
# 32222       176
# 31818       169
# 32209       169
# 32064       167
# 32403       158
# 31817       141
# 32071       140
# 32030       137
# 31814       131
# 32404       121
# 32211       111
# 32070        79
# 32073        68
# 32401        65
# 31651        65
# 32082        61
# 32072        56
# 32402        55
# 31322        53
# 31715        52
# 32400        49
# 31815        40
# 32406        37
# 32202        28
# 31416        28
# 32227        21
# 32405        19
# 31819        12
# 31822         4
# 32407         3
# Name: End station number, Length: 519, dtype: int64

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
stations_lat_lng = df.groupby('End station number')['Duration'].count().sort_values(ascending=False).head(100)

plt.figure(figsize=(25,4))

plt.bar(range(len(stations_lat_lng)),stations_lat_lng)
plt.xticks(range(len(stations_lat_lng)), stations_lat_lng.index, rotation="vertical")
plt.xlim(-0.75, (range(len(stations_lat_lng))-0.25)
plt.savefig("stations.png")
plt.show()
# Out:
#   File "<ipython-input-15-564326fa6e8e>", line 8
#     plt.savefig("stations.png")
#       ^
# SyntaxError: invalid syntax

# %%
# stations_lat_lng = df.groupby('End station number')['Member type'].count()
# # print(pd.DataFrame(stations_lat_lng))
# # ('End station')

# plt.figure(figsize=(100,4))
# plt.bar(range(len(stations_lat_lng)),stations_lat_lng)
# plt.xticks(range(len(stations_lat_lng)), stations_lat_lng.index, rotation=45)
# plt.show()

# %%
df.columns

# %%
# change over the years
change_over_years=df.groupby('Year')['Date'].count()
change_over_years=pd.DataFrame(change_over_years)
change_over_years['percent change']=change_over_years['Date']/max(change_over_years['Date'].values)*100
print(change_over_years)
plt.plot(change_over_years.index, change_over_years['Date'])
plt.xlim(2010,2018)
plt.savefig("years1.png")
plt.show()

# %%
# change over the years
change_over_years=df.groupby('Year')['Date'].count()
change_over_years=pd.DataFrame(change_over_years)
change_over_years['percent change']=change_over_years['Date']/max(change_over_years['Date'].values)*100
print(change_over_years)
plt.plot(change_over_years.index, change_over_years['Date'])
plt.xlim(2010,2018)
plt.xlabel('Year', fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
# plt.ylabel('Installations', fontsize=20)
plt.savefig("year.png")
plt.show()

# %%
# change over the months

df_10=df[df['Year']=='2010']
change_over_months_10=df_10.groupby('Month')['Date'].count()

df_11=df[df['Year']=='2011']
change_over_months_11=df_11.groupby('Month')['Date'].count()

df_12=df[df['Year']=='2012']
change_over_months_12=df_12.groupby('Month')['Date'].count()

df_13=df[df['Year']=='2013']
change_over_months_13=df_13.groupby('Month')['Date'].count()

df_14=df[df['Year']=='2014']
change_over_months_14=df_14.groupby('Month')['Date'].count()

df_15=df[df['Year']=='2015']
change_over_months_15=df_15.groupby('Month')['Date'].count()

df_16=df[df['Year']=='2016']
change_over_months_16=df_16.groupby('Month')['Date'].count()

df_17=df[df['Year']=='2017']
change_over_months_17=df_17.groupby('Month')['Date'].count()

df_18=df[df['Year']=='2018']
change_over_months_18=df_18.groupby('Month')['Date'].count()

# print(pd.DataFrame(change_over_months_15))
plt.figure(figsize=(10,4))
plt.plot(change_over_months_10.index, change_over_months_10.values)
plt.plot(change_over_months_11.index, change_over_months_11.values)
plt.plot(change_over_months_12.index, change_over_months_12.values)
plt.plot(change_over_months_13.index, change_over_months_13.values)
plt.plot(change_over_months_14.index, change_over_months_14.values)
plt.plot(change_over_months_15.index, change_over_months_15.values)
plt.plot(change_over_months_16.index, change_over_months_16.values)
plt.plot(change_over_months_17.index, change_over_months_17.values)
plt.plot(change_over_months_18.index, change_over_months_18.values)
plt.legend()
plt.savefig("months.png")
plt.show()

# %%
change_over_months=df.groupby('Month')['Date'].count()
print(pd.DataFrame(change_over_months))

plt.plot(change_over_months.index, change_over_months.values)
plt.savefig("months2.png")
plt.show()

# %%
# time_hrs = pd.DataFrame(df['Time_Hr'].value_counts())
# time_hrs.head()
# # time_hrs.columns

# %%
df_10=df[df['Year']=='2010']
change_over_time_10=df_10.groupby('Time_Hr')['Date'].count()

df_11=df[df['Year']=='2011']
change_over_time_11=df_11.groupby('Time_Hr')['Date'].count()

df_12=df[df['Year']=='2012']
change_over_time_12=df_12.groupby('Time_Hr')['Date'].count()

df_13=df[df['Year']=='2013']
change_over_time_13=df_13.groupby('Time_Hr')['Date'].count()

df_14=df[df['Year']=='2014']
change_over_time_14=df_14.groupby('Time_Hr')['Date'].count()

df_15=df[df['Year']=='2015']
change_over_time_15=df_15.groupby('Time_Hr')['Date'].count()

df_16=df[df['Year']=='2016']
change_over_time_16=df_16.groupby('Time_Hr')['Date'].count()

df_17=df[df['Year']=='2017']
change_over_time_17=df_17.groupby('Time_Hr')['Date'].count()

df_18=df[df['Year']=='2018']
change_over_time_18=df_18.groupby('Time_Hr')['Date'].count()

# print(pd.DataFrame(change_over_months_15))
plt.plot(change_over_time_10.index, change_over_time_10.values)
plt.plot(change_over_time_11.index, change_over_time_11.values)
plt.plot(change_over_time_12.index, change_over_time_12.values)
plt.plot(change_over_time_13.index, change_over_time_13.values)
plt.plot(change_over_time_14.index, change_over_time_14.values)
plt.plot(change_over_time_15.index, change_over_time_15.values)
plt.plot(change_over_time_16.index, change_over_time_16.values)
plt.plot(change_over_time_17.index, change_over_time_17.values)
plt.plot(change_over_time_18.index, change_over_time_18.values)
# plt.legend()
plt.savefig("time.png")
plt.show()

# %%
sstation_values = pd.DataFrame(df["End station"].value_counts())
sstation_values.head(25).plot(kind="barh")
plt.savefig("End_station.png")

# %%
sstation_values = pd.DataFrame(df["Start station"].value_counts())
plt.figure(figsize=(16,4))
sstation_values.head(25).plot.bar()
plt.savefig("Start_station.png")

# %%
# filename = "bike_station_location.csv"
# location_df = pd.read_csv(filename, index_col=None, header=0)
# location_df.head(2)

# %%
import gmaps

# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)
print(gkey)

# %%
mappy1 = df.loc[(df["End station number"].value_counts()),
                  ["End station number", 'End station lat', 'End station lng']]
mappy1

# %%
locations = mappy1[["End station lat", "End station lng"]]
rating = mappy1.index.astype(float)

# %%
fig = gmaps.figure(map_type="HYBRID")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10000,
                                 point_radius=.0015)

fig.add_layer(heat_layer)
plt.savefig("heatmap1.png")
fig

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations,  weights=rating,
                                 dissipating=False, max_intensity=10000,
                                 point_radius=.002)

# Add layer
fig.add_layer(heat_layer)
plt.savefig("heatmap2.png")
# Display figure
fig
